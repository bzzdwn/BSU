# %%
import random
# модули для математических операций
import math
import numpy as np
import scipy.integrate as integrate # вычисление интегралов
import scipy.special as special
# модули для визуализации
import matplotlib.pyplot as plt
import seaborn as sns
# модули для работы с данными
import pandas as pd
pd.options.display.float_format ='{:,.7f}'.format

# %%
c_1 = 3/4

# %%
math.log(3/(4*math.log(2, math.e)), 2)
# Out:
# 0.11372887366605393

# %%
c_0= 3/(8*math.log(2,math.e)) + 5/8 - 3/8 * math.log(3/(4*math.log(2, math.e)), 2)

# %%
c_0
# Out:
# 1.1233623127085912

# %%
2-3/(8*math.log(2,math.e)) -5/8 + 3/8 * math.log(3/(4*math.log(2, math.e)), 2)
# Out:
# 0.8766376872914088

# %%
x = np.linspace(-1, 1, 100000)

fig, ax = plt.subplots()
ax.plot(x, 2**x, label='real function')
ax.plot(x, c_0+c_1*x, label='approximation')
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
plt.legend()
plt.grid()
plt.show()

# %%
x = np.linspace(2, 4, 100000)

fig, ax = plt.subplots()
ax.scatter([0,1,2,4], [2,3,5,10], label='real function')
ax.plot(x, ((4-x)**3)/46 + 119*x/46 - 8/23, label='approximation')
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
plt.legend()
plt.grid()
plt.show()

# %%
x = np.linspace(0, 3, 100000)
nodes = np.array([0,2,3])
fig, ax = plt.subplots()
ax.scatter(nodes, 2**nodes, label='real function')
ax.plot(x, 5/6*x**2 -1/6*x+1, label='approximation')
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
plt.legend()
plt.grid()
plt.show()

# %%
def P(x):
    return 5/6*x**2 -1/6*x+1

# %%
P(0.5)
# Out:
# 1.125

# %%
27/24
# Out:
# 1.125

# %%
math.log(2, math.e)**3 * 5/2
# Out:
# 0.8325616299723236

# %%
2+2*math.sin(1)-3
# Out:
# 0.682941969615793

# %%
3-2*np.sin(1)
# Out:
# 1.317058030384207

# %%
math.sqrt(6) - 3
# Out:
# -0.5505102572168221

# %%
def f_1(x,y):
    return x+2*np.sin(y) - 3

# %%
def f_2(x,y):
    return x**2 + 2*y**2 - 6

# %%
x = np.linspace(-1, 1, 100000)
y = np.linspace(-1, 1, 100000)
nodes = np.array([0,2,3])
fig, ax = plt.subplots()
ax.plot(x, 1/(x+2)**3, label='approximation')
ax.set_xlabel('x')
ax.set_ylabel('f(x)')
plt.legend()
plt.grid()
plt.show()

# %%
1/np.sqrt(6)
# Out:
# 0.4082482904638631

# %%
2-np.sqrt(6)
# Out:
# -0.4494897427831779

# %%
np.pi/6
# Out:
# 0.5235987755982988

# %%
2**(5/2 - math.sqrt(2)/4)
# Out:
# 4.427359760529305

# %%
(1.233-3.978)/(math.sqrt(2)/2)
# Out:
# -3.882016228714146
